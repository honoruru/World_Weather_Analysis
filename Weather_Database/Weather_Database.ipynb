# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Create set of 2,000 random latitudes and longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# # Get the nearest city using the citipy module.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 784

# %% [markdown]
# # Perform an API call with the OpenWeatherMap.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %% [markdown]
# # Retrieve the weather information from the API call

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description" : city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | yar-sale
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | kaili
# Processing Record 6 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | tyup
# Processing Record 9 of Set 1 | vila
# Processing Record 10 of Set 1 | waipawa
# Processing Record 11 of Set 1 | banda aceh
# Processing Record 12 of Set 1 | grand gaube
# Processing Record 13 of Set 1 | zhangye
# Processing Record 14 of Set 1 | barstow
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | kahului
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | botwood
# Processing Record 22 of Set 1 | san quintin
# Processing Record 23 of Set 1 | cherskiy
# Processing Record 24 of Set 1 | nicolas bravo
# Processing Record 25 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | bengkulu
# Processing Record 30 of Set 1 | lyubinskiy
# Processing Record 31 of Set 1 | muros
# Processing Record 32 of Set 1 | emerald
# Processing Record 33 of Set 1 | longyearbyen
# Processing Record 34 of Set 1 | musoma
# Processing Record 35 of Set 1 | aswan
# Processing Record 36 of Set 1 | half moon bay
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | jieshi
# Processing Record 40 of Set 1 | turukhansk
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | paamiut
# Processing Record 43 of Set 1 | tuatapere
# Processing Record 44 of Set 1 | urgut
# Processing Record 45 of Set 1 | wembley
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | redcar
# Processing Record 48 of Set 1 | krasnyy yar
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | eureka
# Processing Record 1 of Set 2 | chumikan
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 2 | avera
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | haines junction
# Processing Record 7 of Set 2 | houma
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | erenhot
# Processing Record 10 of Set 2 | belyy yar
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | airai
# Processing Record 19 of Set 2 | sargodha
# Processing Record 20 of Set 2 | lata
# Processing Record 21 of Set 2 | husavik
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | whitefish
# Processing Record 24 of Set 2 | yucca valley
# Processing Record 25 of Set 2 | san cristobal
# Processing Record 26 of Set 2 | pemangkat
# Processing Record 27 of Set 2 | atar
# Processing Record 28 of Set 2 | gravdal
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | portland
# Processing Record 35 of Set 2 | itapirapua
# Processing Record 36 of Set 2 | nacala
# Processing Record 37 of Set 2 | weihai
# Processing Record 38 of Set 2 | beira
# Processing Record 39 of Set 2 | isabela
# Processing Record 40 of Set 2 | asfi
# Processing Record 41 of Set 2 | manadhoo
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | khandyga
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | udachnyy
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | isangel
# Processing Record 49 of Set 2 | mandera
# Processing Record 50 of Set 2 | fairbanks
# Processing Record 1 of Set 3 | tasiilaq
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | umm lajj
# Processing Record 5 of Set 3 | saint anthony
# Processing Record 6 of Set 3 | kashary
# Processing Record 7 of Set 3 | namatanai
# Processing Record 8 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 3 | wattegama
# Processing Record 10 of Set 3 | hobyo
# Processing Record 11 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 12 of Set 3 | karlstad
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | gratkorn
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | nouadhibou
# Processing Record 17 of Set 3 | along
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | ola
# Processing Record 21 of Set 3 | huilong
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | khatanga
# Processing Record 24 of Set 3 | sibu
# Processing Record 25 of Set 3 | lagoa
# Processing Record 26 of Set 3 | caravelas
# Processing Record 27 of Set 3 | padang
# Processing Record 28 of Set 3 | itarema
# Processing Record 29 of Set 3 | idlib
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | aurich
# Processing Record 32 of Set 3 | borzya
# Processing Record 33 of Set 3 | trujillo
# Processing Record 34 of Set 3 | constitucion
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | vardo
# Processing Record 37 of Set 3 | quatre cocos
# Processing Record 38 of Set 3 | hamilton
# Processing Record 39 of Set 3 | ouadda
# Processing Record 40 of Set 3 | donskoye
# Processing Record 41 of Set 3 | naujamiestis
# Processing Record 42 of Set 3 | amontada
# Processing Record 43 of Set 3 | kiunga
# Processing Record 44 of Set 3 | nefteyugansk
# Processing Record 45 of Set 3 | beringovskiy
# Processing Record 46 of Set 3 | ngunguru
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | nandyal
# Processing Record 49 of Set 3 | tessalit
# Processing Record 50 of Set 3 | kruisfontein
# Processing Record 1 of Set 4 | torbay
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | namibe
# Processing Record 4 of Set 4 | chapais
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | la rioja
# Processing Record 7 of Set 4 | rawson
# Processing Record 8 of Set 4 | sitka
# Processing Record 9 of Set 4 | egvekinot
# Processing Record 10 of Set 4 | weligama
# Processing Record 11 of Set 4 | tukrah
# Processing Record 12 of Set 4 | carballo
# Processing Record 13 of Set 4 | harper
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | sinnamary
# Processing Record 17 of Set 4 | mount gambier
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | moscow
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | umea
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | sao jose da coroa grande
# Processing Record 24 of Set 4 | cuenca
# Processing Record 25 of Set 4 | tombouctou
# Processing Record 26 of Set 4 | shingu
# Processing Record 27 of Set 4 | hofn
# Processing Record 28 of Set 4 | kaihua
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | leningradskiy
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | ararat
# Processing Record 33 of Set 4 | mnogovershinnyy
# Processing Record 34 of Set 4 | aksu
# Processing Record 35 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 4 | port-gentil
# Processing Record 37 of Set 4 | mahebourg
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | kieta
# Processing Record 40 of Set 4 | alto araguaia
# Processing Record 41 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 4 | idrinskoye
# Processing Record 43 of Set 4 | roma
# Processing Record 44 of Set 4 | wajir
# Processing Record 45 of Set 4 | lazaro cardenas
# Processing Record 46 of Set 4 | labuan
# Processing Record 47 of Set 4 | huarmey
# Processing Record 48 of Set 4 | tigzirt
# Processing Record 49 of Set 4 | porumbacu de jos
# Processing Record 50 of Set 4 | asau
# Processing Record 1 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 5 | methoni
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | manggar
# Processing Record 5 of Set 5 | cuamba
# Processing Record 6 of Set 5 | bereda
# Processing Record 7 of Set 5 | olinda
# Processing Record 8 of Set 5 | labuhan
# Processing Record 9 of Set 5 | goderich
# Processing Record 10 of Set 5 | atuona
# Processing Record 11 of Set 5 | honiara
# Processing Record 12 of Set 5 | wiang sa
# Processing Record 13 of Set 5 | garden city
# Processing Record 14 of Set 5 | balabac
# Processing Record 15 of Set 5 | porterville
# Processing Record 16 of Set 5 | faanui
# Processing Record 17 of Set 5 | sesheke
# Processing Record 18 of Set 5 | goure
# Processing Record 19 of Set 5 | coos bay
# Processing Record 20 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 5 | la libertad
# Processing Record 22 of Set 5 | nishihara
# Processing Record 23 of Set 5 | marshall
# Processing Record 24 of Set 5 | hobart
# Processing Record 25 of Set 5 | carlet
# Processing Record 26 of Set 5 | navapur
# City not found. Skipping...
# Processing Record 27 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 5 | lorengau
# Processing Record 29 of Set 5 | plymouth
# Processing Record 30 of Set 5 | okhtyrka
# Processing Record 31 of Set 5 | simpang
# Processing Record 32 of Set 5 | thayetmyo
# Processing Record 33 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 5 | constantine
# Processing Record 35 of Set 5 | zhigansk
# Processing Record 36 of Set 5 | jamshedpur
# Processing Record 37 of Set 5 | ratnagiri
# Processing Record 38 of Set 5 | tonj
# Processing Record 39 of Set 5 | dryden
# Processing Record 40 of Set 5 | upernavik
# Processing Record 41 of Set 5 | nome
# Processing Record 42 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 5 | winnemucca
# Processing Record 44 of Set 5 | saint-georges
# Processing Record 45 of Set 5 | colac
# Processing Record 46 of Set 5 | oussouye
# Processing Record 47 of Set 5 | rincon
# Processing Record 48 of Set 5 | kijang
# Processing Record 49 of Set 5 | kropotkin
# Processing Record 50 of Set 5 | cidreira
# Processing Record 1 of Set 6 | labrea
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | guelengdeng
# City not found. Skipping...
# Processing Record 4 of Set 6 | kisanga
# Processing Record 5 of Set 6 | kununurra
# Processing Record 6 of Set 6 | sokoto
# Processing Record 7 of Set 6 | betong
# Processing Record 8 of Set 6 | victor harbor
# Processing Record 9 of Set 6 | souillac
# Processing Record 10 of Set 6 | voh
# Processing Record 11 of Set 6 | pimentel
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | wum
# Processing Record 14 of Set 6 | puerto escondido
# Processing Record 15 of Set 6 | wajima
# Processing Record 16 of Set 6 | kendari
# Processing Record 17 of Set 6 | ponta do sol
# Processing Record 18 of Set 6 | bubaque
# Processing Record 19 of Set 6 | basco
# Processing Record 20 of Set 6 | coahuayana
# Processing Record 21 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 22 of Set 6 | nemuro
# Processing Record 23 of Set 6 | kudahuvadhoo
# Processing Record 24 of Set 6 | liaozhong
# Processing Record 25 of Set 6 | faya
# Processing Record 26 of Set 6 | jijiga
# Processing Record 27 of Set 6 | dwarka
# Processing Record 28 of Set 6 | camacha
# Processing Record 29 of Set 6 | ostrogozhsk
# Processing Record 30 of Set 6 | gravelbourg
# Processing Record 31 of Set 6 | solo
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | almeirim
# Processing Record 34 of Set 6 | port macquarie
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | almaznyy
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | standerton
# Processing Record 39 of Set 6 | olden
# Processing Record 40 of Set 6 | myitkyina
# Processing Record 41 of Set 6 | ancud
# Processing Record 42 of Set 6 | havoysund
# Processing Record 43 of Set 6 | tanabe
# Processing Record 44 of Set 6 | ucluelet
# Processing Record 45 of Set 6 | bicester
# Processing Record 46 of Set 6 | sistranda
# Processing Record 47 of Set 6 | kodiak
# Processing Record 48 of Set 6 | pandan
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 6 | young
# Processing Record 1 of Set 7 | boysun
# Processing Record 2 of Set 7 | fortuna
# Processing Record 3 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 7 | ribeira grande
# Processing Record 5 of Set 7 | codrington
# Processing Record 6 of Set 7 | palmer
# Processing Record 7 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 7 | senneterre
# Processing Record 9 of Set 7 | arraial do cabo
# Processing Record 10 of Set 7 | shimoda
# Processing Record 11 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 7 | mariakani
# Processing Record 13 of Set 7 | road town
# Processing Record 14 of Set 7 | lavrentiya
# Processing Record 15 of Set 7 | caloundra
# Processing Record 16 of Set 7 | xam nua
# Processing Record 17 of Set 7 | sargatskoye
# Processing Record 18 of Set 7 | pandharpur
# Processing Record 19 of Set 7 | anadyr
# Processing Record 20 of Set 7 | pisco
# Processing Record 21 of Set 7 | hasaki
# Processing Record 22 of Set 7 | shiringushi
# Processing Record 23 of Set 7 | klaksvik
# Processing Record 24 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | samarai
# Processing Record 27 of Set 7 | hovd
# Processing Record 28 of Set 7 | vao
# Processing Record 29 of Set 7 | tymovskoye
# Processing Record 30 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 7 | mount pleasant
# Processing Record 32 of Set 7 | oranjemund
# Processing Record 33 of Set 7 | khash
# Processing Record 34 of Set 7 | deputatskiy
# Processing Record 35 of Set 7 | port keats
# Processing Record 36 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 7 | garchitorena
# Processing Record 38 of Set 7 | kotar
# Processing Record 39 of Set 7 | sobolevo
# Processing Record 40 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 7 | fernie
# Processing Record 43 of Set 7 | hualmay
# Processing Record 44 of Set 7 | taylorville
# Processing Record 45 of Set 7 | port hedland
# Processing Record 46 of Set 7 | dzhebariki-khaya
# Processing Record 47 of Set 7 | tocopilla
# Processing Record 48 of Set 7 | moose jaw
# Processing Record 49 of Set 7 | valparaiso
# Processing Record 50 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 8 | taoudenni
# Processing Record 2 of Set 8 | trinidad
# Processing Record 3 of Set 8 | gat
# Processing Record 4 of Set 8 | henties bay
# Processing Record 5 of Set 8 | kommunisticheskiy
# Processing Record 6 of Set 8 | kishtwar
# Processing Record 7 of Set 8 | inhambane
# Processing Record 8 of Set 8 | linhares
# Processing Record 9 of Set 8 | vila velha
# Processing Record 10 of Set 8 | martinho campos
# Processing Record 11 of Set 8 | virgilio
# Processing Record 12 of Set 8 | de aar
# Processing Record 13 of Set 8 | kudymkar
# Processing Record 14 of Set 8 | lithgow
# Processing Record 15 of Set 8 | general roca
# Processing Record 16 of Set 8 | shaki
# Processing Record 17 of Set 8 | jalu
# Processing Record 18 of Set 8 | tibu
# Processing Record 19 of Set 8 | boyolangu
# Processing Record 20 of Set 8 | balurghat
# Processing Record 21 of Set 8 | saint-augustin
# Processing Record 22 of Set 8 | bilibino
# Processing Record 23 of Set 8 | saint-joseph
# Processing Record 24 of Set 8 | rassvet
# Processing Record 25 of Set 8 | yenagoa
# Processing Record 26 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 8 | dudinka
# Processing Record 28 of Set 8 | willowmore
# Processing Record 29 of Set 8 | la ronge
# Processing Record 30 of Set 8 | mulhouse
# Processing Record 31 of Set 8 | novyye burasy
# Processing Record 32 of Set 8 | beisfjord
# Processing Record 33 of Set 8 | potosi
# Processing Record 34 of Set 8 | zhezkazgan
# Processing Record 35 of Set 8 | esperance
# Processing Record 36 of Set 8 | pacific grove
# Processing Record 37 of Set 8 | nantucket
# Processing Record 38 of Set 8 | meulaboh
# Processing Record 39 of Set 8 | damghan
# Processing Record 40 of Set 8 | dekar
# Processing Record 41 of Set 8 | guarapari
# Processing Record 42 of Set 8 | belaya gora
# Processing Record 43 of Set 8 | hirara
# Processing Record 44 of Set 8 | merauke
# Processing Record 45 of Set 8 | chivata
# City not found. Skipping...
# Processing Record 46 of Set 8 | iwanai
# Processing Record 47 of Set 8 | eyl
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | masyaf
# Processing Record 50 of Set 8 | velsk
# Processing Record 1 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | maraba
# Processing Record 3 of Set 9 | vila franca do campo
# Processing Record 4 of Set 9 | severo-kurilsk
# Processing Record 5 of Set 9 | laguna
# Processing Record 6 of Set 9 | craig
# Processing Record 7 of Set 9 | qaqortoq
# Processing Record 8 of Set 9 | matara
# Processing Record 9 of Set 9 | vestmannaeyjar
# Processing Record 10 of Set 9 | tomatlan
# Processing Record 11 of Set 9 | lugazi
# Processing Record 12 of Set 9 | touros
# Processing Record 13 of Set 9 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 14 of Set 9 | pavlogradka
# Processing Record 15 of Set 9 | sorland
# Processing Record 16 of Set 9 | mayumba
# Processing Record 17 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 9 | cochrane
# Processing Record 19 of Set 9 | batagay-alyta
# Processing Record 20 of Set 9 | tecoanapa
# Processing Record 21 of Set 9 | mollendo
# Processing Record 22 of Set 9 | iqaluit
# Processing Record 23 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 9 | fethiye
# Processing Record 25 of Set 9 | lotung
# City not found. Skipping...
# Processing Record 26 of Set 9 | saint stephen
# Processing Record 27 of Set 9 | sarai
# Processing Record 28 of Set 9 | grindavik
# Processing Record 29 of Set 9 | salina
# Processing Record 30 of Set 9 | srednekolymsk
# Processing Record 31 of Set 9 | jacareacanga
# Processing Record 32 of Set 9 | sao joao da barra
# Processing Record 33 of Set 9 | nizwa
# Processing Record 34 of Set 9 | markivka
# Processing Record 35 of Set 9 | morondava
# Processing Record 36 of Set 9 | marica
# Processing Record 37 of Set 9 | mangai
# Processing Record 38 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 9 | rastede
# Processing Record 40 of Set 9 | slave lake
# Processing Record 41 of Set 9 | ulaangom
# Processing Record 42 of Set 9 | sao filipe
# Processing Record 43 of Set 9 | ilulissat
# Processing Record 44 of Set 9 | mastic beach
# Processing Record 45 of Set 9 | khorinsk
# Processing Record 46 of Set 9 | balapur
# Processing Record 47 of Set 9 | baghdad
# Processing Record 48 of Set 9 | guerrero negro
# Processing Record 49 of Set 9 | dongsheng
# Processing Record 50 of Set 9 | naryan-mar
# Processing Record 1 of Set 10 | marystown
# Processing Record 2 of Set 10 | ardakan
# Processing Record 3 of Set 10 | hayden
# Processing Record 4 of Set 10 | west bay
# Processing Record 5 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 6 of Set 10 | sayyan
# Processing Record 7 of Set 10 | terney
# Processing Record 8 of Set 10 | turan
# Processing Record 9 of Set 10 | zeya
# Processing Record 10 of Set 10 | ascension
# Processing Record 11 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 12 of Set 10 | seydisehir
# Processing Record 13 of Set 10 | tual
# Processing Record 14 of Set 10 | rakiv lis
# Processing Record 15 of Set 10 | dauriya
# Processing Record 16 of Set 10 | joue-les-tours
# Processing Record 17 of Set 10 | kiomboi
# Processing Record 18 of Set 10 | la palma
# Processing Record 19 of Set 10 | aklavik
# Processing Record 20 of Set 10 | naze
# Processing Record 21 of Set 10 | ketchikan
# Processing Record 22 of Set 10 | chernyshevsk
# Processing Record 23 of Set 10 | calabozo
# Processing Record 24 of Set 10 | yulara
# Processing Record 25 of Set 10 | morwell
# Processing Record 26 of Set 10 | mandalgovi
# Processing Record 27 of Set 10 | vestmanna
# Processing Record 28 of Set 10 | elizabeth city
# Processing Record 29 of Set 10 | uthal
# Processing Record 30 of Set 10 | la paz
# Processing Record 31 of Set 10 | yerbogachen
# Processing Record 32 of Set 10 | saint-prosper
# Processing Record 33 of Set 10 | la cruz
# Processing Record 34 of Set 10 | poronaysk
# Processing Record 35 of Set 10 | cascais
# Processing Record 36 of Set 10 | pilar
# Processing Record 37 of Set 10 | cairns
# Processing Record 38 of Set 10 | pathein
# Processing Record 39 of Set 10 | chara
# Processing Record 40 of Set 10 | berdyuzhye
# City not found. Skipping...
# Processing Record 41 of Set 10 | penzance
# Processing Record 42 of Set 10 | zhob
# Processing Record 43 of Set 10 | maunabo
# Processing Record 44 of Set 10 | yithion
# City not found. Skipping...
# Processing Record 45 of Set 10 | felipe carrillo puerto
# Processing Record 46 of Set 10 | sompeta
# Processing Record 47 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 48 of Set 10 | xuddur
# Processing Record 49 of Set 10 | hulyaypole
# Processing Record 50 of Set 10 | keffi
# Processing Record 1 of Set 11 | shakawe
# Processing Record 2 of Set 11 | college
# Processing Record 3 of Set 11 | kondagaon
# Processing Record 4 of Set 11 | hambantota
# Processing Record 5 of Set 11 | viedma
# Processing Record 6 of Set 11 | paragominas
# Processing Record 7 of Set 11 | ulety
# Processing Record 8 of Set 11 | vanimo
# Processing Record 9 of Set 11 | ossora
# Processing Record 10 of Set 11 | walvis bay
# Processing Record 11 of Set 11 | rio cuarto
# Processing Record 12 of Set 11 | atocha
# Processing Record 13 of Set 11 | rudnya
# Processing Record 14 of Set 11 | corbelia
# Processing Record 15 of Set 11 | necochea
# Processing Record 16 of Set 11 | shache
# Processing Record 17 of Set 11 | mount isa
# Processing Record 18 of Set 11 | ostersund
# Processing Record 19 of Set 11 | ahipara
# Processing Record 20 of Set 11 | beipiao
# Processing Record 21 of Set 11 | petrokamenskoye
# Processing Record 22 of Set 11 | asosa
# Processing Record 23 of Set 11 | eidfjord
# Processing Record 24 of Set 11 | sulphur
# Processing Record 25 of Set 11 | lakatoro
# Processing Record 26 of Set 11 | dauphin
# Processing Record 27 of Set 11 | bonavista
# Processing Record 28 of Set 11 | port pirie
# Processing Record 29 of Set 11 | santa marta de tormes
# Processing Record 30 of Set 11 | baruun-urt
# Processing Record 31 of Set 11 | dickinson
# Processing Record 32 of Set 11 | nagorsk
# Processing Record 33 of Set 11 | adrar
# Processing Record 34 of Set 11 | mayo
# Processing Record 35 of Set 11 | biak
# Processing Record 36 of Set 11 | kentau
# Processing Record 37 of Set 11 | mbini
# Processing Record 38 of Set 11 | kenai
# Processing Record 39 of Set 11 | chegutu
# Processing Record 40 of Set 11 | lima
# Processing Record 41 of Set 11 | olafsvik
# Processing Record 42 of Set 11 | syracuse
# Processing Record 43 of Set 11 | goya
# Processing Record 44 of Set 11 | talnakh
# Processing Record 45 of Set 11 | kroderen
# City not found. Skipping...
# Processing Record 46 of Set 11 | nanortalik
# Processing Record 47 of Set 11 | howard springs
# Processing Record 48 of Set 11 | te anau
# Processing Record 49 of Set 11 | sioux lookout
# Processing Record 50 of Set 11 | puerto madryn
# Processing Record 1 of Set 12 | liuhe
# Processing Record 2 of Set 12 | praia
# Processing Record 3 of Set 12 | ilhabela
# Processing Record 4 of Set 12 | beni mazar
# Processing Record 5 of Set 12 | launceston
# Processing Record 6 of Set 12 | beloha
# Processing Record 7 of Set 12 | dovolnoye
# Processing Record 8 of Set 12 | medea
# Processing Record 9 of Set 12 | qeshm
# Processing Record 10 of Set 12 | velyka lepetykha
# Processing Record 11 of Set 12 | palia kalan
# Processing Record 12 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 12 | bay roberts
# Processing Record 14 of Set 12 | port hawkesbury
# Processing Record 15 of Set 12 | coquimbo
# Processing Record 16 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 12 | atikokan
# Processing Record 18 of Set 12 | hanzhong
# Processing Record 19 of Set 12 | gold coast
# Processing Record 20 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 21 of Set 12 | maningrida
# Processing Record 22 of Set 12 | saint-gaudens
# Processing Record 23 of Set 12 | zhanaozen
# Processing Record 24 of Set 12 | samur
# Processing Record 25 of Set 12 | baykit
# Processing Record 26 of Set 12 | nicoya
# Processing Record 27 of Set 12 | guiratinga
# Processing Record 28 of Set 12 | sabha
# Processing Record 29 of Set 12 | irtyshskiy
# Processing Record 30 of Set 12 | norman wells
# Processing Record 31 of Set 12 | sawai madhopur
# Processing Record 32 of Set 12 | barabai
# Processing Record 33 of Set 12 | tendo
# Processing Record 34 of Set 12 | dunedin
# Processing Record 35 of Set 12 | pontes e lacerda
# Processing Record 36 of Set 12 | mariinsk
# Processing Record 37 of Set 12 | kashi
# Processing Record 38 of Set 12 | gyal
# Processing Record 39 of Set 12 | rocha
# Processing Record 40 of Set 12 | port blair
# Processing Record 41 of Set 12 | comodoro rivadavia
# Processing Record 42 of Set 12 | coihaique
# Processing Record 43 of Set 12 | easthampton
# Processing Record 44 of Set 12 | fort morgan
# Processing Record 45 of Set 12 | vynohradove
# Processing Record 46 of Set 12 | wilmington
# Processing Record 47 of Set 12 | sechura
# Processing Record 48 of Set 12 | den helder
# Processing Record 49 of Set 12 | ust-nera
# Processing Record 50 of Set 12 | guadalupe
# Processing Record 1 of Set 13 | bud
# Processing Record 2 of Set 13 | baker city
# Processing Record 3 of Set 13 | marsaxlokk
# Processing Record 4 of Set 13 | vostok
# Processing Record 5 of Set 13 | belmonte
# Processing Record 6 of Set 13 | strezhevoy
# Processing Record 7 of Set 13 | korogwe
# City not found. Skipping...
# Processing Record 8 of Set 13 | maldonado
# Processing Record 9 of Set 13 | andselv
# City not found. Skipping...
# Processing Record 10 of Set 13 | tulagi
# Processing Record 11 of Set 13 | santa rosa
# Processing Record 12 of Set 13 | noumea
# Processing Record 13 of Set 13 | ekibastuz
# Processing Record 14 of Set 13 | monatele
# City not found. Skipping...
# Processing Record 15 of Set 13 | pyapon
# Processing Record 16 of Set 13 | bismarck
# Processing Record 17 of Set 13 | kidal
# Processing Record 18 of Set 13 | khorramshahr
# Processing Record 19 of Set 13 | dharchula
# Processing Record 20 of Set 13 | birin
# Processing Record 21 of Set 13 | tocantinopolis
# City not found. Skipping...
# Processing Record 22 of Set 13 | banes
# Processing Record 23 of Set 13 | arica
# Processing Record 24 of Set 13 | sisimiut
# Processing Record 25 of Set 13 | murray bridge
# Processing Record 26 of Set 13 | kurilsk
# Processing Record 27 of Set 13 | mapiripan
# Processing Record 28 of Set 13 | maun
# Processing Record 29 of Set 13 | ust-tsilma
# Processing Record 30 of Set 13 | angoche
# Processing Record 31 of Set 13 | kavaratti
# Processing Record 32 of Set 13 | karatuzskoye
# Processing Record 33 of Set 13 | lydenburg
# Processing Record 34 of Set 13 | hailar
# Processing Record 35 of Set 13 | kokopo
# Processing Record 36 of Set 13 | logrono
# Processing Record 37 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 38 of Set 13 | hellvik
# Processing Record 39 of Set 13 | abu kamal
# Processing Record 40 of Set 13 | broome
# Processing Record 41 of Set 13 | lompoc
# Processing Record 42 of Set 13 | murchison
# Processing Record 43 of Set 13 | marzuq
# Processing Record 44 of Set 13 | albanel
# Processing Record 45 of Set 13 | la asuncion
# Processing Record 46 of Set 13 | aguilas
# Processing Record 47 of Set 13 | medina
# Processing Record 48 of Set 13 | gdynia
# Processing Record 49 of Set 13 | ye
# City not found. Skipping...
# Processing Record 50 of Set 13 | novoseleznevo
# Processing Record 1 of Set 14 | coracora
# Processing Record 2 of Set 14 | lumbac
# Processing Record 3 of Set 14 | northam
# Processing Record 4 of Set 14 | marsh harbour
# Processing Record 5 of Set 14 | yinchuan
# Processing Record 6 of Set 14 | veraval
# Processing Record 7 of Set 14 | middelkerke
# Processing Record 8 of Set 14 | acapulco
# Processing Record 9 of Set 14 | stephenville
# Processing Record 10 of Set 14 | cockburn town
# Processing Record 11 of Set 14 | ngerengere
# Processing Record 12 of Set 14 | imbituba
# Processing Record 13 of Set 14 | alyangula
# Processing Record 14 of Set 14 | phan thiet
# Processing Record 15 of Set 14 | gorontalo
# Processing Record 16 of Set 14 | bambanglipuro
# Processing Record 17 of Set 14 | zhuanghe
# Processing Record 18 of Set 14 | maniitsoq
# Processing Record 19 of Set 14 | maumere
# Processing Record 20 of Set 14 | oneida
# Processing Record 21 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 14 | igarka
# Processing Record 23 of Set 14 | ostrovnoy
# Processing Record 24 of Set 14 | ustka
# Processing Record 25 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 14 | ridgecrest
# Processing Record 27 of Set 14 | turayf
# Processing Record 28 of Set 14 | mudanjiang
# Processing Record 29 of Set 14 | virginia beach
# Processing Record 30 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 14 | mazagao
# Processing Record 32 of Set 14 | arman
# Processing Record 33 of Set 14 | santa isabel do rio negro
# Processing Record 34 of Set 14 | son la
# Processing Record 35 of Set 14 | tautira
# Processing Record 36 of Set 14 | barmer
# Processing Record 37 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 14 | peace river
# Processing Record 39 of Set 14 | brae
# Processing Record 40 of Set 14 | sarkand
# Processing Record 41 of Set 14 | mawlamyine
# Processing Record 42 of Set 14 | mbanza-ngungu
# Processing Record 43 of Set 14 | champerico
# Processing Record 44 of Set 14 | pochutla
# Processing Record 45 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 48 of Set 14 | palakkad
# Processing Record 49 of Set 14 | barth
# Processing Record 50 of Set 14 | soyo
# Processing Record 1 of Set 15 | puerto pinasco
# City not found. Skipping...
# Processing Record 2 of Set 15 | zyryanka
# Processing Record 3 of Set 15 | banjarmasin
# Processing Record 4 of Set 15 | port angeles
# Processing Record 5 of Set 15 | barwani
# Processing Record 6 of Set 15 | mitsamiouli
# Processing Record 7 of Set 15 | wau
# Processing Record 8 of Set 15 | ouidah
# Processing Record 9 of Set 15 | geraldton
# Processing Record 10 of Set 15 | vettavalam
# Processing Record 11 of Set 15 | gillette
# Processing Record 12 of Set 15 | sarapul
# Processing Record 13 of Set 15 | solhan
# Processing Record 14 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 15 of Set 15 | calama
# Processing Record 16 of Set 15 | chabahar
# Processing Record 17 of Set 15 | tigil
# Processing Record 18 of Set 15 | lisakovsk
# Processing Record 19 of Set 15 | shanghai
# Processing Record 20 of Set 15 | manta
# Processing Record 21 of Set 15 | afmadu
# City not found. Skipping...
# Processing Record 22 of Set 15 | cayenne
# Processing Record 23 of Set 15 | solnechnyy
# Processing Record 24 of Set 15 | san juan
# Processing Record 25 of Set 15 | reinosa
# Processing Record 26 of Set 15 | funtua
# Processing Record 27 of Set 15 | kasempa
# Processing Record 28 of Set 15 | narsaq
# Processing Record 29 of Set 15 | shizuishan
# Processing Record 30 of Set 15 | amatenango del valle
# Processing Record 31 of Set 15 | danilov
# Processing Record 32 of Set 15 | saurimo
# Processing Record 33 of Set 15 | trairi
# Processing Record 34 of Set 15 | tongren
# Processing Record 35 of Set 15 | tommot
# Processing Record 36 of Set 15 | shetpe
# Processing Record 37 of Set 15 | zhigalovo
# Processing Record 38 of Set 15 | kirando
# Processing Record 39 of Set 15 | the valley
# Processing Record 40 of Set 15 | richards bay
# Processing Record 41 of Set 15 | navolato
# Processing Record 42 of Set 15 | xinyu
# Processing Record 43 of Set 15 | margate
# Processing Record 44 of Set 15 | port lincoln
# Processing Record 45 of Set 15 | vallenar
# Processing Record 46 of Set 15 | darnah
# Processing Record 47 of Set 15 | neyshabur
# Processing Record 48 of Set 15 | dong hoi
# Processing Record 49 of Set 15 | muzhi
# Processing Record 50 of Set 15 | grand-santi
# Processing Record 1 of Set 16 | almenara
# Processing Record 2 of Set 16 | starobaltachevo
# Processing Record 3 of Set 16 | lubango
# Processing Record 4 of Set 16 | ukiah
# Processing Record 5 of Set 16 | xingcheng
# Processing Record 6 of Set 16 | iberia
# Processing Record 7 of Set 16 | burica
# City not found. Skipping...
# Processing Record 8 of Set 16 | fengzhen
# Processing Record 9 of Set 16 | khandbari
# Processing Record 10 of Set 16 | bowmore
# Processing Record 11 of Set 16 | assinovskaya
# Processing Record 12 of Set 16 | kuusamo
# Processing Record 13 of Set 16 | ponta delgada
# Processing Record 14 of Set 16 | pauini
# Processing Record 15 of Set 16 | kalmunai
# Processing Record 16 of Set 16 | chancay
# Processing Record 17 of Set 16 | auki
# Processing Record 18 of Set 16 | straumen
# Processing Record 19 of Set 16 | dabhol
# Processing Record 20 of Set 16 | boguchany
# Processing Record 21 of Set 16 | awbari
# Processing Record 22 of Set 16 | mehamn
# Processing Record 23 of Set 16 | grants
# Processing Record 24 of Set 16 | okhotsk
# Processing Record 25 of Set 16 | cam ranh
# Processing Record 26 of Set 16 | ceres
# Processing Record 27 of Set 16 | elko
# Processing Record 28 of Set 16 | gizo
# Processing Record 29 of Set 16 | shintomi
# Processing Record 30 of Set 16 | san antonio
# Processing Record 31 of Set 16 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 16 | baculin
# Processing Record 34 of Set 16 | harnosand
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# # Add the data to a new DataFrame.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Bethel  41.3712  -73.4140     78.94        81          90        4.61
# 1    Yar-Sale  66.8333   70.8333     49.17        67          99       11.45
# 2     Rikitea -23.1203 -134.9692     74.12        78         100       14.72
# 3       Vaini -21.2000 -175.2000     69.96        83          75        8.05
# 4       Kaili  -3.4626  120.2147     75.15        68          82        2.48
# 5    Thompson  55.7435  -97.8558     69.96        56          75        4.61
# 6        Tyup  42.7276   78.3648     69.51        52          91        3.44
# 7        Vila  42.0304   -8.1588     53.74        83           1        4.99
# 8     Waipawa -41.4122  175.5153     54.45        64           0        2.21
# 9  Banda Aceh   5.5577   95.3222     82.04        75          55       13.87
#
#   Weather Description Country                 Date
# 0     overcast clouds      US  2021-07-28 01:25:40
# 1     overcast clouds      RU  2021-07-28 01:25:40
# 2          light rain      PF  2021-07-28 01:25:41
# 3       broken clouds      TO  2021-07-28 01:25:41
# 4       broken clouds      ID  2021-07-28 01:25:41
# 5       broken clouds      CA  2021-07-28 01:25:42
# 6     overcast clouds      KG  2021-07-28 01:21:35
# 7           clear sky      PT  2021-07-28 01:25:43
# 8           clear sky      NZ  2021-07-28 01:23:08
# 9       broken clouds      ID  2021-07-28 01:25:44

# %%
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bethel      US  41.3712  -73.4140     78.94        81          90
# 1    Yar-Sale      RU  66.8333   70.8333     49.17        67          99
# 2     Rikitea      PF -23.1203 -134.9692     74.12        78         100
# 3       Vaini      TO -21.2000 -175.2000     69.96        83          75
# 4       Kaili      ID  -3.4626  120.2147     75.15        68          82
# 5    Thompson      CA  55.7435  -97.8558     69.96        56          75
# 6        Tyup      KG  42.7276   78.3648     69.51        52          91
# 7        Vila      PT  42.0304   -8.1588     53.74        83           1
# 8     Waipawa      NZ -41.4122  175.5153     54.45        64           0
# 9  Banda Aceh      ID   5.5577   95.3222     82.04        75          55
#
#    Wind Speed Weather Description
# 0        4.61     overcast clouds
# 1       11.45     overcast clouds
# 2       14.72          light rain
# 3        8.05       broken clouds
# 4        2.48       broken clouds
# 5        4.61       broken clouds
# 6        3.44     overcast clouds
# 7        4.99           clear sky
# 8        2.21           clear sky
# 9       13.87       broken clouds

# %% [markdown]
# # Export the DataFrame as a CSV file

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
